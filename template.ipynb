# %% [markdown]
# <img align="left" src="https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/tapi-logo-small.png" />
#
# This notebook free for educational reuse under [Creative Commons CC BY License](https://creativecommons.org/licenses/by/4.0/).
#
# Created by [Firstname Lastname](https://) for the 2023 Text Analysis Pedagogy Institute, with support from [Constellate](https://constellate.org).
#
# For questions/comments/improvements, email author@email.address.<br />
# ____

# %% [markdown]
# # `Course Title` `1/2/3`
#
# This is lesson `1` of 3 in the educational series on `TOPIC`. This notebook is intended `to teach XXX and introduce the concepts of XXXX`.
#
# **Audience:** `Teachers` / `Learners` / `Researchers`
#
# **Use case:** `Tutorial` / `How-To` / `Reference` / `Explanation`
#
# `Include the use case definition from [here](https://constellate.org/docs/documentation-categories)`
#
# **Difficulty:** `Beginner` / `Intermediate` / `Advanced`
#
# `Beginner assumes users are relatively new to Python and Jupyter Notebooks. The user is helped step-by-step with lots of explanatory text.`
# `Intermediate assumes users are familiar with Python and have been programming for 6+ months. Code makes up a larger part of the notebook and basic concepts related to Python are not explained.`
# `Advanced assumes users are very familiar with Python and have been programming for years, but they may not be familiar with the process being explained.`
#
# **Completion time:** `90 minutes`
#
# **Knowledge Required:**
# ```
# * Python basics (variables, flow control, functions, lists, dictionaries)
# * Object-oriented programming (classes, instances, inheritance)
# * Regular Expressions (`re`, character classes)
#
# These should be general skills but can mention a particular library
# ```
#
# **Knowledge Recommended:**
# ```
# * Basic file operations (open, close, read, write)
# * Data cleaning with `Pandas`
# ```
#
# **Learning Objectives:**
# After this lesson, learners will be able to:
# ```
# 1. Describe and implement an XXXX for XXXX
# 2. Convert XXXX into XXXX for the purpose of XXXX
# 3. Develop a workflow in order to XXXX
# 4. Be familiar with XXXXX resources for pursuing the topic
# ```
# **Research Pipeline:**
# ```
# 1. Research steps before this notebook
# 2. **The skills in this notebook**
# 3. Steps after this notebook
# 4. Final steps
# ```
# ___

# %% [markdown]
# # Required Python Libraries
# `List out any libraries used and what they are used for`
# * [Tesseract](https://tesseract-ocr.github.io/) for performing [optical character recognition](https://docs.constellate.org/key-terms/#ocr).
# * [Pandas](https://pandas.pydata.org/) for manipulating and cleaning data.
# * [Pdf2image](https://pdf2image.readthedocs.io/en/latest/) for converting pdf files into image files.
#
# ## Install Required Libraries

# %%
### Install Libraries ###

# Using !pip installs
# !pip install pdf2image

# Using %%bash magic with apt-get and yes prompt

# %%
# %%bash
# apt-get install tesseract-ocr
# y

# %%
### Import Libraries ###
import urllib.request
import os

# %% [markdown]
# # Required Data
#
# `List out the data sources, including their formats and a few sentences describing the data. Include a link to the data source description, if possible.`
#
# **Data Format:**
# * image files (.jpg, .png)
# * document files (.pdf)
# * plain text (.txt)
#
# **Data Source:**
# * [Detroit Open Data Portal](https://data.detroitmi.gov/datasets/detroitmi::dpd-citizen-complaints/about)
#
# **Data Quality/Bias:**
# `Analysis of this data should consider the following quality and bias issues...`
#
# **Data Description:**
#
# `This lesson uses XXXX data in XXX format from XXXX source. Additional details about the data used.`
#
# ## Download Required Data

# %%
### Grab files with console `wget` and `mv` ###
# !wget https://github.com/tesseract-ocr/tessdata/raw/main/eng.traineddata
# !mv eng.traineddata /usr/share/tesseract-ocr/4.00/tessdata/eng.traineddata

# %%
### Grab a single file and supply name ###
urllib.request.urlretrieve('https://file.address.txt', 'filename.txt')

# %%
### Retrieve multiple files using a list ###

download_urls = [
    'https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/sample_01.pdf',
    'https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/sample_02.pdf',
    'https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/sample_03.pdf'
]

for url in download_urls:
    urllib.request.urlretrieve(url, url.rsplit('/', 1)[-1])

# %%
### Retrieve multiple files using a list ###
### With data folder creation using os ###

# Files hosted somewhere else (don't store data on GitHub)

# Check if a folder exists to hold pdfs. If not, create it.
if os.path.exists('sample_pdfs') == False:
    os.mkdir('sample_pdfs')

# Move into our new directory
os.chdir('sample_pdfs')

# Download the pdfs into our directory
import urllib.request
download_urls = [
    'https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/sample_01.pdf',
    'https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/sample_02.pdf',
    'https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/sample_03.pdf'
]

for url in download_urls:
    urllib.request.urlretrieve(url, url.rsplit('/', 1)[-1])
    
## Move back out of our directory
os.chdir('../')

## Success message
print('Folder created and pdfs added.')

# %%
### Constellate Example ###

# Importing your dataset with a dataset ID
import constellate
# Pull in the sampled dataset (1500 documents) that matches `dataset_id`
# in the form of a gzipped JSON lines file.
# The .get_dataset() method downloads the gzipped JSONL file
# to the /data folder and returns a string for the file name and location
dataset_file = constellate.get_dataset(dataset_id)

# To download the full dataset (up to a limit of 25,000 documents),
# request it first in the builder environment. See the Constellate Client
# documentation at: https://constellate.org/docs/constellate-client
# Then use the `constellate.download` method show below.
#dataset_file = constellate.download(dataset_id, 'jsonl')

# %% [markdown]
# # Introduction
#
# ```
# Introduce the lesson topic. Answer questions such as:
# * Why is it useful?
# * Why should we learn it?
# * Who might use it?
# * Where has it been used by scholars/industry?
# * What do we need to do it?
# * What subjects are included in the notebooks?
# * What is not in this notebook? Where should we look for it?
# ```

# %%
import time
import requests
from bs4 import BeautifulSoup
import pathlib

# %%
target = pathlib.Path('sci-pages')

# %%
for p in target.glob("*.html"):
    print(p)
# Out:
# sci-pages/sci-F.html
# sci-pages/sci-S.html
# sci-pages/sci-J.html
# sci-pages/sci-K.html
# sci-pages/sci-R.html
# sci-pages/sci-G.html
# sci-pages/sci-L.html
# sci-pages/sci-Y.html
# sci-pages/sci-U.html
# sci-pages/sci-T.html
# sci-pages/sci-A.html
# sci-pages/sci-X.html
# sci-pages/sci-M.html
# sci-pages/sci-N.html
# sci-pages/sci-W.html
# sci-pages/sci-B.html
# sci-pages/sci-C.html
# sci-pages/sci-V.html
# sci-pages/sci-O.html
# sci-pages/sci-Z.html
# sci-pages/sci-Q.html
# sci-pages/sci-D.html
# sci-pages/sci-H.html
# sci-pages/sci-I.html
# sci-pages/sci-E.html
# sci-pages/sci-P.html

# %%
parsed_target = pathlib.Path('parsed_sci-pages')
parsed_target.mkdir(exist_ok = True)

for p in target.glob("*.html"):
    soup = BeautifulSoup(p.read_text(), 'html.parser')
    f = parsed_target / pathlib.Path(str(p.stem) + '.txt')
    text = ""
    for a in soup.select("td > p > a"):
        text += a.parent.text
        # f.write_text(a.parent.text)
        # print(a.parent.text)
    f.write_text(text)

# %%
out = pathlib.Path('all_species')
out.write_text(page_text)
# Out:
# 0

# %%
import re
from bs4 import BeautifulSoup
import pathlib

# %%
parsed_target = pathlib.Path('parsed_sci-pages')
parsed_target.mkdir(exist_ok = True)

all_species = []
target = pathlib.Path('sci-pages')

for p in target.glob("*.html"):
    soup = BeautifulSoup(p.read_text(), 'html.parser')
    f = parsed_target / pathlib.Path(str(p.stem) + '.txt')
    p_tags = soup.select("td > p")
    p_text = [p.text for p in p_tags]
    lines = []
    for chunk in p_text:
        lines.extend(chunk.split('\n'))
    lines = [l for l in lines if len(l) > 0]
    with open(f, 'w', encoding = 'utf-8') as speciesout:
        for l in lines:
            speciesout.write(l + '\n')
    all_species.extend(lines)

# %%
len(all_species)
# Out:
# 29814

# %%
with open('all_species.txt', 'w', encoding = 'utf-8') as outfile:
    for s in all_species:
        outfile.write(s + '\n')

# %%
with open('all_species.txt', 'r', encoding = 'utf-8') as infile:
    names = infile.read().splitlines() # another way of removing newlines

# %%
len(names)
# Out:
# 29814

# %%
without_p = 0

for n in names:
    if not ')' in n:
        without_p += 1

# %%
without_p
# Out:
# 0

# %%
import re

# %%
match_species = re.compile('(.+)\(([0-9]+)\)')
results = []
for n in names:
    found = re.findall(match_species, n)
    if len(found) != 1:
        print(found)
    else:
        results.append(found[0])

# %%
for r in results:
    if len(r) != 2:
        print(r)

# %%
species_pics = {name: int(count) for name, count in results}

# %%
species_pics
# Out:
# {'Fabaceae sp. ': 3,
#  'Fabiana imbricata ': 5,
#  'Fabronia pusilla ': 7,
#  'Facelis retusa ': 3,
#  'Facheiroa ulei ': 2,
#  'Fagonia chilensis ': 2,
#  'Fagonia laevis ': 105,
#  'Fagonia pachyacantha ': 48,
#  'Fagopyrum esculentum ': 24,
#  'Fagopyrum tataricum ': 1,
#  'Fagraea berteriana ': 10,
#  'Fagus grandifolia ': 19,
#  'Fagus orientalis ': 1,
#  'Fagus sylvatica ': 46,
#  'Faidherbia albida ': 60,
#  'Faisherbia albida ': 2,
#  'Falcataria moluccana ': 10,
#  'Falkia repens ': 6,
#  'Fallopia convolvulus ': 6,
#  'Fallopia dumetorum ': 5,
#  'Fallopia japonica ': 25,
#  'Fallopia japonica var. japonica ': 1,
#  'Fallopia sachalinensis ': 5,
#  'Fallopia scandens  ': 4,
#  'Falluga paradoxa ': 1,
#  'Fallugia paradoxa ': 102,
#  'Famatina cisandina ': 4,
#  'Faradaya splendida ': 1,
#  'Farfugium japonicum ': 8,
#  'Farfugium japonicum var. giganteum ': 4,
#  'Fascicularia bicolor ': 2,
#  'Fascicularia pitcairnifolia ': 1,
#  'Fatsia japonica ': 20,
#  'Faucaria britteniae ': 1,
#  'Faucaria tigrina ': 5,
#  'Faucaria tuberculosa ': 2,
#  'Fauchea laciniata ': 1,
#  'Faurea galpinii ': 7,
#  'Faurea rochetiana ': 4,
#  'Faurea saligna ': 19,
#  'Fauria crista-galli ': 3,
#  'Faxonia pusilla ': 1,
#  'Feijoa sellowiana ': 18,
#  'Felicia amelloides ': 4,
#  'Felicia echinata ': 5,
#  'Felicia fruticosa ': 5,
#  'Felicia muricata ': 1,
#  'Fendlera rupicola ': 14,
#  'Fendlerella utahensis ': 11,
#  'Fenestraria aurantiaca ': 3,
#  'Fenestraria rhopalophylla ': 1,
#  'Fenestraria rhopalophylla ssp. aurantiaca ': 5,
#  'Fenestraria rhopalophylla ssp. rhopalophylla ': 4,
#  'Ferocactus acanthodes ': 1,
#  'Ferocactus alamosanus ': 2,
#  'Ferocactus cylindraceae ': 5,
#  'Ferocactus cylindraceus ': 349,
#  'Ferocactus cylindraceus ssp. cylindraceus ': 11,
#  'Ferocactus cylindraceus ssp. tortulispinus ': 19,
#  'Ferocactus cylindraceus var. lecontei ': 6,
#  'Ferocactus diguetii ': 17,
#  'Ferocactus echidnae var. echidnae ': 1,
#  'Ferocactus emeryi ': 3,
#  'Ferocactus emoryi ': 8,
#  'Ferocactus emoryi ssp. rectispinus ': 4,
#  'Ferocactus fordii ': 1,
#  'Ferocactus fordii var. fordii ': 1,
#  'Ferocactus glaucescens ': 3,
#  'Ferocactus gracilis ': 21,
#  'Ferocactus gracilis var. coloratus ': 3,
#  'Ferocactus gracilis var. gracilis ': 9,
#  'Ferocactus hamatacanthus ': 14,
#  'Ferocactus hamatacanthus var. hamatacanthus ': 10,
#  'Ferocactus herrerae ': 4,
#  'Ferocactus histrix ': 3,
#  'Ferocactus latispinus ': 1,
#  'Ferocactus macrodiscus ': 2,
#  'Ferocactus macrodiscus var. macrodiscus ': 2,
#  'Ferocactus peninsulae ': 5,
#  'Ferocactus peninsulae ssp. townsendianus ': 4,
#  'Ferocactus pilosus ': 11,
#  'Ferocactus pottsii ': 1,
#  'Ferocactus pottsii var. alamosanus ': 3,
#  'Ferocactus recurvus ': 2,
#  'Ferocactus robustus ': 5,
#  'Ferocactus sinuatus ': 1,
#  'Ferocactus stainesii ': 1,
#  'Ferocactus townsendianus var. townsendianus ': 6,
#  'Ferocactus viridescens ': 71,
#  'Ferocactus wislizeni ': 29,
#  'Ferocactus wislizenii ': 3,
#  'Ferraria antherosa ': 1,
#  'Ferraria crispa ': 13,
#  'Ferraria crispa ssp. nortieri ': 1,
#  'Ferraria divaricata ': 3,
#  'Ferraria ferrariola ': 3,
#  'Ferula communis ': 16,
#  'Festcue pallescens ': 2,
#  'Festuca arundinacea ': 24,
#  'Festuca brachyphylla ': 8,
#  'Festuca brachyphylla ssp. breviculmis ': 2,
#  'Festuca brachyphylla ssp. coloradoensis ': 1,
#  'Festuca bromoides ': 10,
#  'Festuca californica ': 36,
#  'Festuca californica ssp. californica ': 1,
#  'Festuca calva ': 4,
#  'Festuca drymeja ': 1,
#  'Festuca elmeri ': 6,
#  'Festuca glauca ': 6,
#  'Festuca idahoensis ': 33,
#  'Festuca kingii ': 14,
#  'Festuca microstachys ': 34,
#  'Festuca minutiflora ': 7,
#  'Festuca myuros ': 25,
#  'Festuca occidentalis ': 20,
#  'Festuca octoflora ': 12,
#  'Festuca perennis ': 85,
#  'Festuca pratensis ': 10,
#  'Festuca roemeri ': 1,
#  'Festuca rubra ': 14,
#  'Festuca rubra ssp. rubra ': 2,
#  'Festuca saximontana ': 5,
#  'Festuca saximontana var. purpusiana ': 3,
#  'Festuca sp. ': 4,
#  'Festuca subulata ': 6,
#  'Festuca subuliflora ': 7,
#  'Festuca temulenta ': 2,
#  'Festuca trachyphylla ': 2,
#  'Festuca viridula ': 8,
#  'Fibigia clypeata ': 1,
#  'Fibigia eriocarpa ': 1,
#  'Ficaria verna ': 9,
#  'Ficinia nodosa ': 3,
#  'Ficinia spiralis ': 5,
#  'Ficinia truncata ': 1,
#  'Ficus abutilifolia ': 21,
#  'Ficus alii ': 2,
#  'Ficus altissima ': 1,
#  'Ficus audrey ': 1,
#  'Ficus auriculata ': 13,
#  'Ficus bahiensis ': 13,
#  'Ficus benghalensis ': 44,
#  'Ficus benjamina ': 29,
#  'Ficus benjamina var. Benjamina ': 4,
#  'Ficus burkei ': 25,
#  'Ficus carica ': 49,
#  'Ficus citrifolia ': 1,
#  'Ficus craterostoma ': 16,
#  'Ficus dammaropsis ': 2,
#  'Ficus deltiodea ': 2,
#  'Ficus deltoidea ': 2,
#  'Ficus elastica ': 13,
#  'Ficus glumosa ': 7,
#  'Ficus ingens ': 23,
#  'Ficus insipida subsp. insipida ': 2,
#  'Ficus lutea ': 5,
#  'Ficus lyrata ': 11,
#  'Ficus macrophylla ': 18,
#  'Ficus microcarpa ': 9,
#  'Ficus microcarpa var. nitida ': 16,
#  'Ficus mysorensis ': 6,
#  'Ficus natalensis ': 5,
#  'Ficus palmeri ': 5,
#  'Ficus petiolaris ': 42,
#  'Ficus prolixa ': 2,
#  'Ficus pumila ': 28,
#  'Ficus pumila var. pumila ': 3,
#  'Ficus racemosa ': 4,
#  'Ficus religiosa ': 9,
#  'Ficus repens ': 1,
#  'Ficus rubiginosa ': 3,
#  'Ficus rumphii ': 7,
#  'Ficus sansibarica ': 4,
#  'Ficus socotrana ': 5,
#  'Ficus sp. ': 5,
#  'Ficus sur ': 21,
#  'Ficus sycomorus ': 17,
#  'Ficus tettensis ': 17,
#  'Ficus thonningii ': 1,
#  'Ficus tinctoria subsp. tinctoria ': 1,
#  'Ficus triangularis ': 5,
#  'Ficus trigonata ': 1,
#  'Ficus umbellata ': 2,
#  'Ficus variegata ': 2,
#  'Ficus villosa ': 3,
#  'Ficus virens ': 2,
#  'Ficus waikinsiana ': 2,
#  'Ficus watkinsiana ': 5,
#  'Filago californica ': 12,
#  'Filago gallica ': 4,
#  'Filago pyramidata ': 2,
#  'Filago pyramidata var. pyramidata ': 21,
#  'Filago vulgaris ': 1,
#  'Filicium decipiens ': 1,
#  'Filipendula hexapetala ': 3,
#  'Filipendula kamtschatica ': 1,
#  'Filipendula purpurea ': 4,
#  'Filipendula rubra ': 4,
#  'Filipendula ulmaria ': 13,
#  'Fimbristylis autumnalis ': 2,
#  'Fimbristylis cymosa umbello-capitata ': 2,
#  'Fimbristylis miliacea ': 7,
#  'Fimbristylis puberula var. interior ': 1,
#  'Fimbristylis thermalis ': 33,
#  'Fimbristylis vahlii ': 6,
#  'Firmiania simplex ': 1,
#  'Fissidens bryoides ': 3,
#  'Fissidens crispus ': 3,
#  'Fissidens grandifrons ': 13,
#  'Fissidens pauperculus ': 7,
#  'Fissidens sublimbatus ': 6,
#  'Fissidens ventricosus ': 2,
#  'Fittonia albivenis ': 3,
#  'Fitzroya cupressoides ': 11,
#  'Flacourtia rukam ': 2,
#  'Flaveria anomala ': 3,
#  'Flaveria brownii ': 3,
#  'Flaveria chlorifolia ': 5,
#  'Flaveria linearis ': 8,
#  'Flaveria oppositifolia ': 6,
#  'Flaveria trinervia ': 2,
#  'Fleischmannia incarnata ': 7,
#  'Fleischmannia sonorae ': 4,
#  'Flemingia strobilifera ': 2,
#  'Flexitrichum gracile ': 14,
#  'Floerkea proserpinacoides ': 17,
#  'Florestina tripteris ': 4,
#  'Flourensia cernua ': 12,
#  'Flourensia laurifolia ': 2,
#  'Flourensia oolepis ': 1,
#  'Flueggea neowawraea ': 4,
#  'Flyriella parryi ': 4,
#  'Fockea crispa ': 2,
#  'Fockea edulis ': 1,
#  'Foeniculum vulgare ': 110,
#  'Fontinalis antipyretica ': 5,
#  'Fontinalis howellii ': 2,
#  'Fontinalis hypnoides ': 2,
#  'Fontinalis neomexicana ': 1,
#  'Forestiera ': 1,
#  'Forestiera angustifolia ': 13,
#  'Forestiera arizonica ': 1,
#  'Forestiera neomexicana ': 1,
#  'Forestiera pubescens ': 56,
#  'Forestiera reticulata ': 1,
#  'Forquieria splendens ': 2,
#  'Forsythia sp. ': 7,
#  'Forsythia X intermedia ': 4,
#  'Fortunella margarita ': 6,
#  'Fossombronia ': 17,
#  'Fosterella rubsyi ': 1,
#  'Fothergilla gardenii ': 7,
#  'Fothergilla monticola ': 10,
#  'Fouquiera splendens ': 1,
#  'Fouquieria columnaris ': 60,
#  'Fouquieria diguetii ': 52,
#  'Fouquieria fasciculata ': 1,
#  'Fouquieria macdougalii ': 8,
#  'Fouquieria sp. ': 5,
#  'Fouquieria splendens ': 206,
#  'Fouquieria splendens ssp. splendens ': 114,
#  'Fragaria ananassa ': 2,
#  'Fragaria chiloensis ': 104,
#  'Fragaria gracilis ': 1,
#  'Fragaria moschata ': 6,
#  'Fragaria moupinensis ': 3,
#  'Fragaria sp. ': 7,
#  'Fragaria vesca ': 92,
#  'Fragaria vesca var. bracteata ': 5,
#  'Fragaria virginiana ': 93,
#  'Fragaria virginiana ssp. glauca ': 1,
#  'Fragaria virginiana ssp. platypetala ': 5,
#  'Fragaria viridis ': 6,
#  'Fragaria x ananassa ': 10,
#  'Frailea castanea ': 3,
#  'Frailea mammifera ssp. angelesiae ': 2,
#  'Frailea pumila ': 2,
#  'Frailea pygmaea ssp. pygmaea ': 2,
#  'Francoa appendiculata ': 8,
#  'Francoa ramosa ': 3,
#  'Francoa sonchifolia ': 4,
#  'Frangula alnus  ': 15,
#  'Frangula californica ': 86,
#  'Frangula californica ssp. californica ': 68,
#  'Frangula californica ssp. crassifolia ': 4,
#  'Frangula californica ssp. cuspidata ': 47,
#  'Frangula californica ssp. occidentalis ': 13,
#  'Frangula californica ssp. tomentella ': 59,
#  'Frangula californica ssp. ursina ': 2,
#  'Frangula purshiana ': 32,
#  'Frangula purshiana ssp. purshiana ': 25,
#  'Frangula purshiana ssp. ultramafica ': 10,
#  'Frangula rubra ': 24,
#  'Frangula rubra ssp. modocensis ': 2,
#  'Frangula rubra ssp. obtusissima ': 7,
#  'Frangula rubra ssp. rubra ': 6,
#  'Frangula rupestris ': 4,
#  'Frankenia gypsophila ': 6,
#  'Frankenia hirsuta ': 6,
#  'Frankenia jamesii ': 2,
#  'Frankenia laevis ': 6,
#  'Frankenia palmeri ': 16,
#  'Frankenia pulverulenta ': 15,
#  'Frankenia saligna ': 8,
#  'Frankenia salina ': 88,
#  'Franklinia alatamaha ': 8,
#  'Frasera albicaulis ': 55,
#  'Frasera albicaulis var. modocensis ': 62,
#  'Frasera albicaulis var. nitida ': 46,
#  'Frasera albomarginata ': 40,
#  'Frasera albomarginata var. albomarginata ': 10,
#  'Frasera albomarginata var. induta ': 5,
#  'Frasera fastigiata ': 3,
#  'Frasera gypsicola ': 7,
#  'Frasera neglecta ': 59,
#  'Frasera parryi ': 60,
#  'Frasera puberulenta ': 28,
#  'Frasera speciosa ': 192,
#  'Frasera tubulosa ': 61,
#  'Frasera umpquaensis ': 24,
#  'Fraxinus americana ': 16,
#  'Fraxinus angustifolia ': 18,
#  'Fraxinus angustifolia ssp. oxycarpa ': 4,
#  'Fraxinus anomala ': 30,
#  'Fraxinus anomala var. anomala  ': 3,
#  'Fraxinus chinensis ': 1,
#  'Fraxinus cuspidata ': 5,
#  'Fraxinus cuspidata var. cuspidata ': 9,
#  'Fraxinus dipetala ': 73,
#  'Fraxinus excelsior ': 16,
#  'Fraxinus gooddingii ': 1,
#  'Fraxinus greggii ': 13,
#  'Fraxinus hopeinsis ': 1,
#  'Fraxinus latifolia ': 60,
#  'Fraxinus nigra ': 13,
#  'Fraxinus ornus ': 13,
#  'Fraxinus parryi ': 2,
#  'Fraxinus pennsylvanica ': 17,
#  'Fraxinus quadrangulata ': 3,
#  'Fraxinus sp. ': 1,
#  'Fraxinus uhdei ': 9,
#  'Fraxinus velutina ': 55,
#  'Fredolia aretioides ': 3,
#  'Freesia ': 6,
#  'Freesia alba x leichtlinii ': 10,
#  'Freesia laxa ': 2,
#  'Freesia refracta ': 9,
#  'Freesia viridis ': 7,
#  'Fremontia californica ': 4,
#  'Fremontodendron -californicum ': 9,
#  'Fremontodendron californicum ': 198,
#  'Fremontodendron californicum ssp. californicum ': 4,
#  'Fremontodendron californicum ssp. decumbens ': 2,
#  'Fremontodendron decumbens ': 39,
#  'Fremontodendron mexicanum ': 34,
#  'Freycinetia banksii ': 1,
#  'Freycinetia cumingiana ': 2,
#  'Freycinetia impavida ': 3,
#  'Fritillaria acmopetala ': 2,
#  'Fritillaria affinis ': 393,
#  'Fritillaria affinis var. affinis ': 18,
#  'Fritillaria affinis var. tristulis ': 28,
#  'Fritillaria agrestis ': 130,
#  'Fritillaria atropurpurea ': 136,
#  'Fritillaria bicolor var. bicolor ': 12,
#  'Fritillaria biflora ': 87,
#  'Fritillaria biflora var. biflora ': 54,
#  'Fritillaria biflora var. ineziana ': 16,
#  'Fritillaria bithynica ': 4,
#  'Fritillaria brandegeei ': 47,
#  'Fritillaria camschatcensis ': 28,
#  'Fritillaria carica ': 2,
#  'Fritillaria conica ': 2,
#  'Fritillaria davisii ': 5,
#  'Fritillaria eastwoodiae ': 117,
#  'Fritillaria eastwoodiae vel aff. ': 1,
#  'Fritillaria falcata ': 58,
#  'Fritillaria gentneri ': 65,
#  'Fritillaria gibbosa ': 1,
#  'Fritillaria glauca ': 68,
#  'Fritillaria gracilis ': 8,
#  'Fritillaria graeca ssp. thessala var. meteora ': 1,
#  'Fritillaria grayana ssp. martha roderick ': 2,
#  'Fritillaria imperialis ': 1,
#  'Fritillaria involucrata ': 4,
#  'Fritillaria kurdica ssp. turkish glow ': 2,
#  'Fritillaria lanceolata ': 13,
#  'Fritillaria lanceolata var. tristulis ': 14,
#  'Fritillaria latifolia ': 2,
#  'Fritillaria liliacea ': 182,
#  'Fritillaria meleagris ': 20,
#  'Fritillaria meleagris ssp. saturnus ': 1,
#  'Fritillaria messanensis ': 2,
#  'Fritillaria michailovskyi ssp. yellow form ': 1,
#  'Fritillaria micrantha ': 103,
#  'Fritillaria montana ': 2,
#  'Fritillaria ojaiensis ': 56,
#  'Fritillaria orientalis ': 4,
#  'Fritillaria pallidiflora ': 2,
#  'Fritillaria pelinaea ': 3,
#  'Fritillaria pinetorum ': 46,
#  'Fritillaria pluriflora ': 129,
#  'Fritillaria pontica ': 3,
#  'Fritillaria pudica ': 57,
#  'Fritillaria purdyi ': 118,
#  'Fritillaria pyrenaica ': 4,
#  'Fritillaria pyrenaica ssp. lutea ': 1,
#  'Fritillaria recurva ': 142,
#  'Fritillaria sp. ': 8,
#  'Fritillaria striata ': 97,
#  'Fritillaria tubiformis ssp. moggridgei ': 5,
#  'Fritillaria ussuriensis ': 13,
#  'Fritillaria viridea ': 25,
#  'Froelichia arizonica ': 23,
#  'Froelichia floridana ': 11,
#  'Froelichia gracilis  ': 8,
#  'Froelichia interrupta ': 5,
#  'Froelichia xantusii ': 13,
#  'Fruiticose lichen ': 2,
#  'Frullania bolanderi ': 1,
#  'Frullania tamarisci ': 12,
#  'Fryeella gardneri ': 2,
#  'Fuchsia boliviana ': 6,
#  'Fuchsia bracelineae ': 1,
#  'Fuchsia cordifolia ': 1,
#  'Fuchsia dependens ': 2,
#  'Fuchsia encliandra ': 1,
#  'Fuchsia excorticata ': 3,
#  'Fuchsia magellanica ': 7,
#  'Fuchsia paniculata ': 4,
#  'Fuchsia procumbens ': 3,
#  'Fuchsia sanctae-rosae ': 2,
#  'Fuchsia sp. ': 3,
#  'Fuchsia thymifolia var. variegata ': 1,
#  'Fuchsia triphylla ': 2,
#  'Fucus distichus ': 14,
#  'Fucus gardneri ': 16,
#  'Fucus gardneri (=f. distichus) ': 1,
#  'Fucus sp. ': 1,
#  'Fucus vesiculosus ': 8,
#  'Fumana thymifolia ': 1,
#  'Fumaria capreolata ': 38,
#  'Fumaria densiflora ': 1,
#  'Fumaria muralis ': 38,
#  'Fumaria officinalis ': 23,
#  'Fumaria parviflora ': 8,
#  'Fumaria vaillantii ': 2,
#  'Funaria hygrometrica ': 11,
#  'Funaria muhlenbergii  ': 5,
#  'Funaria sp. ': 1,
#  'Funastrum crispum ': 34,
#  'Funastrum cyanchoides var. hartwegii ': 1,
#  'Funastrum cynanchoides ': 14,
#  'Funastrum cynanchoides ssp. hartwegii ': 5,
#  'Funastrum cynanchoides var. hartwegii ': 82,
#  'Funastrum hartwegii ': 17,
#  'Funastrum hirtellum ': 102,
#  'Funastrum utahense ': 28,
#  'Furcraea foetida ': 2,
#  'Furcraea guatemalensis ': 1,
#  'Furcraea macdougalii ': 2,
#  'Furcraea sp. ': 3,
#  'Sabal bermudana ': 3,
#  'Sabal blackburniana ': 2,
#  'Sabal causiarum ': 1,
#  'Sabal etonia ': 1,
#  'Sabal mexicana ': 2,
#  'Sabal palmetto ': 4,
#  'Sabal uresana ': 2,
#  'Sabal yapa ': 3,
#  'Sabatia angularis ': 1,
#  'Sabatia arenicola ': 3,
#  'Sabatia campanulata ': 5,
#  'Sabatia campestris ': 1,
#  'Sabatia difformis ': 1,
#  'Sabatia sp. ': 1,
#  'Sabatia stellaris ': 2,
#  'Sabulina californica ': 4,
#  'Sabulina decumbens ': 3,
#  'Sabulina nuttallii var. gracilis ': 5,
#  'Sabulina stricta ': 4,
#  'Saccharum officinarum ': 1,
#  'Saccharum ravennae ': 7,
#  'Saccharum sp. ': 2,
#  'Sacciolepis indica ': 2,
#  'Sachsia polycephala ': 4,
#  'Sacoila lanceolata ': 2,
#  'Sadleria cyantheoides ': 2,
#  'Sadleria cyatheoides ': 20,
#  'Sadleria pallida ': 9,
#  'Sadleria souleyetiana ': 10,
#  'Sadleria squarrosa ': 8,
#  'Sadleria unisora ': 9,
#  'Sageretia filiformis ': 1,
#  'Sageretia wrightii ': 1,
#  'Sagina apetala ': 35,
#  'Sagina decumbens ': 5,
#  'Sagina decumbens ssp. occidentalis ': 5,
#  'Sagina decurrens ssp. occidentalis ': 5,
#  'Sagina maritima ': 2,
#  'Sagina maxima ssp. crassicaulis ': 23,
#  'Sagina nodosa ': 8,
#  'Sagina nodosa ssp. borealis  ': 2,
#  'Sagina procumbens ': 19,
#  'Sagina saginoides ': 40,
#  'Sagina subulata ': 4,
#  'Sagittaria brevirostra ': 4,
#  'Sagittaria cuneata ': 27,
#  'Sagittaria graminea ': 6,
#  'Sagittaria graminea ssp. graminea ': 4,
#  'Sagittaria lancifolia ': 2,
#  'Sagittaria latifolia ': 45,
#  'Sagittaria longiloba ': 5,
#  'Sagittaria montevidensis ': 4,
#  'Sagittaria montevidensis ssp. calycina ': 51,
#  'Sagittaria rigida ': 31,
#  'Sagittaria sanfordii ': 25,
#  'Sagittaria trifolia ': 3,
#  'Saintpaulia ionantha ': 3,
#  'Saintpaulia shumensis ': 1,
#  'Saintpaulia teitensis ': 1,
#  'Salazaria mexicana ': 27,
#  'Salicornia bigelovii ': 5,
#  'Salicornia brachiata ': 1,
#  'Salicornia depressa ': 7,
#  'Salicornia pacifica ': 74,
#  'Salicornia perennis ': 1,
#  'Salicornia rubra ': 11,
#  'Salicornia sp. ': 2,
#  'Salicornia subterminalis ': 2,
#  'Salicornia virginica ': 5,
#  'Saline hookeri ': 1,
#  'Salix alba ': 2,
#  'Salix alpina ': 12,
#  'Salix amygdaloides  ': 13,
#  'Salix arctica ': 20,
#  'Salix arctica var. petraea ': 3,
#  'Salix arctophila ': 1,
#  'Salix atrocinerea ': 2,
#  'Salix babylonica ': 16,
#  'Salix barclayi ': 1,
#  'Salix bebbiana  ': 14,
#  'Salix bonplandiana ': 7,
#  'Salix boothii ': 11,
#  'Salix brachycarpa ssp. brachycarpa ': 2,
#  'Salix brachycarpa var. brachycarpa ': 5,
#  'Salix breweri ': 7,
#  'Salix calcicola ': 4,
#  'Salix candida ': 4,
#  'Salix caprea ': 14,
#  'Salix cinerea ': 5,
#  'Salix commutata ': 3,
#  'Salix delnortensis ': 15,
#  'Salix discolor  ': 31,
#  'Salix discolor cf. ': 1,
#  'Salix eastwoodiae ': 24,
#  'Salix eleagnos ': 9,
#  'Salix eriocephala ': 2,
#  'Salix eriocephala var. ligulifolia ': 2,
#  'Salix eriocephala var. watsonii ': 6,
#  'Salix exigua ': 52,
#  'Salix exigua var. exigua ': 15,
#  'Salix exigua var. hindsiana ': 18,
#  'Salix fragilis ': 5,
#  'Salix geyeriana ': 8,
#  'Salix glabra ': 7,
#  'Salix gooddingii ': 46,
#  'Salix helvetica ': 1,
#  'Salix herbacea ': 4,
#  'Salix hookeriana ': 30,
#  'Salix humboldtiana ': 6,
#  'Salix humilis var. humilis  ': 13,
#  'Salix interior  ': 12,
#  'Salix jepsonii ': 4,
#  'Salix laevigata ': 77,
#  'Salix lanata ': 3,
#  'Salix lasiandra ': 3,
#  'Salix lasiandra var. caudata ': 6,
#  'Salix lasiandra var. lasiandra ': 45,
#  'Salix lasiolepis ': 117,
#  'Salix lemmonii ': 34,
#  'Salix ligulifolia ': 4,
#  'Salix lucida ': 1,
#  'Salix lucida caudata cf. ': 1,
#  'Salix lucida ssp. lasiandra ': 4,
#  'Salix lucida var. caudata ': 6,
#  'Salix lutea ': 10,
#  'Salix matsudana ': 1,
#  'Salix melanopis ': 2,
#  'Salix melanopsis ': 9,
#  'Salix nigra ': 2,
#  'Salix nivalis ': 28,
#  'Salix orestera ': 25,
#  'Salix paradoxa ': 5,
#  'Salix petiolaris  ': 12,
#  'Salix petrophila ': 61,
#  'Salix planifolia ': 9,
#  'Salix polaris ': 6,
#  'Salix prolixa ': 14,
#  'Salix purpurea ': 11,
#  'Salix reticulata ': 15,
#  'Salix reticulata ssp. nivalis ': 2,
#  'Salix retusa ': 12,
#  'Salix rigida var. watsonii ': 1,
#  'Salix rosmarinifolia ': 5,
#  'Salix scouleriana ': 51,
#  'Salix sessilifolia ': 2,
#  'Salix sitchensis ': 61,
#  'Salix sp. ': 32,
#  'Salix viminalis ': 2,
#  'Salix waldsteiniana ': 3,
#  'Salix X sepulcralis ': 5,
#  'Salix Xrubens ': 4,
#  'Salpichroa origanifolia ': 10,
#  'Salpiglossis sinuata ': 8,
#  'Salpinctium natalense ': 1,
#  'Salsoa paulsenii ': 3,
#  'Salsola australis ': 20,
#  'Salsola kali ': 17,
#  'Salsola paulsenii ': 40,
#  'Salsola soda ': 60,
#  'Salsola sp. ': 2,
#  'Salsola tragus ': 114,
#  'Saltera sarcocolla ': 2,
#  'Saltugilia australis ': 19,
#  'Saltugilia caruifolia ': 36,
#  'Saltugilia latimeri ': 13,
#  'Saltugilia splendens ': 12,
#  'Saltugilia splendens ssp. grantii ': 11,
#  'Saltugilia splendens ssp. splendens ': 18,
#  'Salvia aethiopis ': 34,
#  'Salvia africana ': 4,
#  'Salvia africana-caerulea ': 6,
#  'Salvia africana-lutea ': 3,
#  'Salvia alamosana ': 8,
#  'Salvia alata ': 1,
#  'Salvia alborosea ': 1,
#  'Salvia anguicoma ': 1,
#  'Salvia apiana ': 108,
#  'Salvia apiana x salvia chionopeplica ': 1,
#  'Salvia areolata ': 1,
#  'Salvia argentea ': 23,
#  'Salvia atrocalyx ': 1,
#  'Salvia atrocyanea ': 3,
#  'Salvia aurea ': 8,
#  'Salvia azurea ': 1,
#  'Salvia azurea var. grandiflora ': 7,
#  'Salvia ballotiflora ': 7,
#  'Salvia barrelieri ': 7,
#  'Salvia benthamiana ': 1,
#  'Salvia betulifolia ': 20,
#  'Salvia betulifolia var. betulifolia ': 3,
#  'Salvia blepharophylla ': 3,
#  'Salvia brandegeei ': 11,
#  'Salvia buchananii ': 3,
#  'Salvia bullulata ': 7,
#  'Salvia cacaliifolia ': 12,
#  'Salvia canariensis ': 8,
#  'Salvia canariensis var. candidissima ': 2,
#  'Salvia canriensis ': 1,
#  'Salvia carduacea ': 138,
#  'Salvia cedrosensis ': 9,
#  'Salvia chamaedryoides ': 9,
#  'Salvia chamelaegnea ': 4,
#  'Salvia chiapensis ': 4,
#  'Salvia chionopeplica ': 4,
#  'Salvia chrysophylla ': 1,
#  'Salvia cinnabarina ': 2,
#  'Salvia clevelandii ': 67,
#  'Salvia clevelandii X leucophylla ': 1,
#  'Salvia coahuilensis ': 1,
#  'Salvia coccinea ': 6,
#  'Salvia columbariae ': 169,
#  'Salvia columbariae var. columbariae ': 4,
#  'Salvia columbiana ': 2,
#  'Salvia concolor ': 9,
#  'Salvia confertiflora ': 7,
#  'Salvia consobrina ': 1,
#  'Salvia corrugata ': 13,
#  'Salvia cyanea ': 1,
#  'Salvia cylindriflora ': 1,
#  'Salvia d ': 1,
#  'Salvia darcyi ': 8,
#  'Salvia desoleana ': 3,
#  'Salvia discolor ': 10,
#  'Salvia divinorum ': 9,
#  'Salvia dolomitica ': 5,
#  'Salvia dominica ': 1,
#  'Salvia dorisiana ': 7,
#  'Salvia dorrii ': 69,
#  'Salvia dorrii ssp. dorrii var. dorrii ': 2,
#  'Salvia dorrii ssp. mearnsii ': 5,
#  'Salvia dorrii var. clokeyi ': 10,
#  'Salvia dorrii var. dorrii ': 16,
#  'Salvia dorrii var. incana ': 26,
#  'Salvia dorrii var. pilosa ': 45,
#  'Salvia elegans ': 13,
#  'Salvia elegans var. sonorensis ': 9,
#  'Salvia emaciata ': 7,
#  'Salvia eremostachya ': 13,
#  'Salvia excelsa ': 1,
#  'Salvia fallax ': 2,
#  'Salvia farinacea ': 7,
#  'Salvia farinaceae ': 3,
#  'Salvia flava ': 3,
#  'Salvia flocculosa ': 4,
#  'Salvia forskohlei ': 3,
#  'Salvia forsskaolei ': 6,
#  'Salvia fruticosa ': 2,
#  'Salvia funerea ': 58,
#  'Salvia gesneriiflora ': 7,
#  'Salvia gesneriifolia ': 3,
#  'Salvia gillesii ': 1,
#  'Salvia glabrescens ': 7,
#  'Salvia glutinosa ': 8,
#  'Salvia goldmanii ': 10,
#  'Salvia greatae ': 30,
#  'Salvia greggii ': 32,
#  'Salvia guaranitica ': 6,
#  'Salvia hapalophylla ': 1,
#  'Salvia henryi ': 12,
#  'Salvia herrerae ': 2,
#  'Salvia hierosolymitana ': 3,
#  'Salvia hispanica ': 12,
#  'Salvia holwayi ': 2,
#  'Salvia indica ': 4,
#  'Salvia involucrata ': 5,
#  'Salvia iodantha ': 1,
#  'Salvia jamensis ': 2,
#  'Salvia karwinskiana ': 1,
#  'Salvia karwinskii ': 1,
#  'Salvia koyamae ': 4,
#  'Salvia lanceolata ': 2,
#  'Salvia lanicaulis ': 1,
#  'Salvia lasiocephala ': 6,
#  'Salvia lemmonii ': 29,
#  'Salvia leucantha ': 21,
#  'Salvia leucophylla ': 91,
#  'Salvia libanensis ': 4,
#  'Salvia littae ': 5,
#  'Salvia longispicata ': 10,
#  'Salvia lyrata ': 1,
#  'Salvia macrophylla ': 4,
#  'Salvia madrensis ': 3,
#  'Salvia marci ': 1,
#  'Salvia matudae ': 1,
#  'Salvia medusa ': 1,
#  'Salvia melissaeflora ': 1,
#  'Salvia melissodora ': 20,
#  'Salvia mellifera ': 156,
#  'Salvia mexicana ': 25,
#  'Salvia microphylla ': 18,
#  'Salvia miltiorrhiza ': 9,
#  'Salvia misella ': 2,
#  'Salvia mocinoi ': 5,
#  'Salvia mohavensis ': 34,
#  'Salvia muelleri ': 4,
#  'Salvia muirii ': 7,
#  'Salvia multifida ': 7,
#  'Salvia munzii ': 33,
#  'Salvia muscarioides ': 9,
#  'Salvia nana ': 2,
#  'Salvia nellifera ': 1,
#  'Salvia nemorosa ': 8,
#  'Salvia nervata ': 8,
#  'Salvia nubilorum ': 1,
#  'Salvia nutans ': 1,
#  'Salvia occidentalis ': 1,
#  'Salvia occlusa ': 1,
#  'Salvia officinalis ': 26,
#  'Salvia oxyphora ': 11,
#  'Salvia pachyphylla ': 107,
#  'Salvia palealis ': 1,
#  'Salvia palestina ': 1,
#  'Salvia pallida ': 1,
#  'Salvia patens ': 6,
#  'Salvia peninsularis ': 1,
#  'Salvia pennellii ': 1,
#  'Salvia peregrina ': 1,
#  'Salvia pinguifolia ': 5,
#  'Salvia polystachya ': 4,
#  'Salvia pomifera ssp. pomifera ': 5,
#  'Salvia praestans ': 3,
#  'Salvia pratensis ': 15,
#  'Salvia psilantha ': 1,
#  'Salvia psilostachya ': 1,
#  'Salvia puberula ': 9,
#  'Salvia pulchella ': 1,
#  'Salvia purpurea ': 7,
#  'Salvia radula ': 3,
#  'Salvia regla ': 12,
#  'Salvia reptans ': 3,
#  'Salvia rhinosina ': 5,
#  'Salvia rhodostephana ': 1,
#  'Salvia roscida ': 2,
#  'Salvia rosmarinus ': 1,
#  'Salvia rubescens ': 2,
#  'Salvia rubrifaux ': 1,
#  'Salvia sagittata ': 12,
#  'Salvia sclarea ': 35,
#  'Salvia scutellarioides ': 6,
#  'Salvia secundiflora ': 1,
#  'Salvia sellowiana ': 1,
#  'Salvia semiatrata ': 8,
#  'Salvia sharpii ': 1,
#  'Salvia silvarum ': 1,
#  'Salvia sinaloensis ': 7,
#  'Salvia somalensis ': 1,
#  'Salvia sonomensis ': 103,
#  'Salvia sp. ': 42,
#  'Salvia spathacea ': 99,
#  'Salvia spellenbergii ': 4,
#  'Salvia splendens ': 8,
#  'Salvia stepposa ': 3,
#  'Salvia subincisa ': 11,
#  'Salvia subrubens ': 1,
#  'Salvia subscandens ': 1,
#  'Salvia texana ': 3,
#  'Salvia tiliaefolia ': 12,
#  'Salvia townsendii ': 22,
#  'Salvia transylvanica ': 2,
#  'Salvia trichostephana ': 1,
#  'Salvia uliginosa ': 11,
#  'Salvia univerticillata ': 1,
#  'Salvia urica ': 1,
#  'Salvia vaseyi ': 27,
#  'Salvia vazquezii ': 2,
#  'Salvia verbenaca ': 11,
#  'Salvia verticillata ': 10,
#  'Salvia verticillata ssp. verticillata ': 6,
#  'Salvia viridis ': 5,
#  'Salvia wagneriana ': 7,
#  'Salvia whitehousei ': 10,
#  'Salvia x guaranitica ': 7,
#  'Salvia x hybrida ': 10,
#  'Salvia x jamensis ': 5,
#  'Salvia x superba (salvia sylvestris Ã\x97 villicaulis) ': 3,
#  'Salvia x sylvestris ': 2,
#  'Salvia Xbernardina ': 18,
#  'Salvia xpalmeri ': 3,
#  'Salvia yunnanensis ': 3,
#  'Salvinia auriculata ': 3,
#  'Salvinia minima ': 5,
#  'Salvinia molesta ': 16,
#  'Salvinia molesta (left) and salvinia minima (right) ': 1,
#  'Samanea saman ': 19,
#  'Sambucus caerulea ': 1,
#  'Sambucus canadensis ': 2,
#  'Sambucus canadensis var. canadensis ': 2,
#  'Sambucus cerulea ': 7,
#  'Sambucus ebulus ': 9,
#  'Sambucus melanocarpa ': 2,
#  'Sambucus mexicana ': 5,
#  'Sambucus microbotorys ': 1,
#  'Sambucus nigra ': 21,
#  'Sambucus nigra ssp. caerulea ': 146,
#  'Sambucus nigra ssp. canadensis ': 61,
#  'Sambucus nigra ssp. cerulea ': 33,
#  'Sambucus nigra subsp. caerulea ': 1,
#  'Sambucus pubens ': 2,
#  'Sambucus racemosa ': 85,
#  'Sambucus racemosa var. melanocarpa ': 5,
#  'Sambucus racemosa var. racemosa ': 82,
#  'Sambucus sp. ': 6,
#  'Samolus ebracteatus ': 7,
#  'Samolus ebracteatus ssp. cuneatus ': 4,
#  'Samolus parviflorus ': 21,
#  'Samolus repens ': 2,
#  'Samolus valerandi ': 5,
#  'Sanchezia speciosa ': 1,
#  'Sanguinaria canadensis ': 58,
#  'Sanguinaria canadensis ssp. flore plena ': 7,
#  'Sanguinaria canadensis ssp. multiplex ': 2,
#  'Sanguisorba canadensis ': 6,
#  'Sanguisorba minor ': 13,
#  'Sanguisorba minor ssp. muricata ': 8,
#  'Sanguisorba officinalis ': 20,
#  'Sanguisorba sitchensis ': 2,
#  'Sanguisorba sp. ': 1,
#  'Sanicula arctopoides ': 125,
#  'Sanicula arguta ': 48,
#  'Sanicula bipinnata ': 53,
#  'Sanicula bipinnatifida ': 118,
#  'Sanicula bipinnatifida var. flava ': 2,
#  'Sanicula chinensis ': 1,
#  'Sanicula crassicaulis ': 121,
#  'Sanicula crassicaulis var. nudicaulis ': 7,
#  'Sanicula graveolens ': 58,
#  'Sanicula hoffmannii ': 22,
#  'Sanicula laciniata ': 39,
#  'Sanicula marilandica ': 7,
#  'Sanicula maritima ': 24,
#  'Sanicula odorata  ': 3,
#  'Sanicula peckiana ': 19,
#  'Sanicula saxatilis ': 11,
#  'Sanicula tracyi ': 9,
#  'Sanicula tuberosa ': 81,
#  'Sanicula tuberosas ': 1,
#  'Saniculata bipinnata ': 1,
#  'Sanionia uncinata ': 3,
#  'Sannantha sp. ': 1,
#  'Sansevieria aethiopica ': 4,
#  'Sansevieria cylindrica ': 6,
#  'Sansevieria ehrenbergii ': 1,
#  'Sansevieria sp. ': 9,
#  'Sansevieria suffruticosa ': 1,
#  "Sansevieria trifasciata 'Hahnii' ": 2,
#  'Sansevieria trifasciata var. trifasciata ': 1,
#  'Sanseviieria pearsonii ': 1,
#  'Santalum album ': 2,
#  'Santalum ellipticum ': 5,
#  'Santalum haleakalae ': 6,
#  'Santalum insulare var. raiateense ': 7,
#  'Santalum paniculatum ': 10,
#  'Santalum paniculatum var. paniculatum ': 2,
#  'Santolina chamaecyparissus ': 13,
#  'Santolina impressa ': 2,
#  'Santolina pinnata ': 3,
#  'Santolina rosmarinifolia ': 2,
#  'Sanvitalia abertii ': 43,
#  'Sanvitalia procumbens ': 5,
#  'Sapindus drummondii ': 1,
#  'Sapindus saponaria ': 20,
#  'Sapium ': 1,
#  'Sapium sebiferum ': 1,
#  'Saponaria lutea ': 4,
#  'Saponaria ocymoides ': 27,
#  'Saponaria officinalis ': 60,
#  'Saponaria pumila ': 1,
#  'Saraca declinata ': 1,
#  'Saraca indica ': 1,
#  'Sarcobatus baileyi ': 14,
#  'Sarcobatus vermiculatus ': 55,
#  'Sarcocaulon crassicaule ': 2,
#  'Sarcocaulon inerme ': 1,
#  'Sarcocaulon vaderietiae ': 2,
#  'Sarcochilus hartmannii ': 1,
#  'Sarcococca hookeriana ': 2,
#  'Sarcococca hookeriana var. humilis ': 7,
#  'Sarcococca ruscifolia ': 1,
#  'Sarcococca saligna ': 4,
#  'Sarcocornia utahensis ': 11,
#  'Sarcocoronia pacifica ': 1,
#  'Sarcodes sanguinea ': 227,
#  'Sarcodia antarctica ': 2,
#  'Sarcodiotheca divaricata ': 2,
#  'Sarcodiotheca ecuadoreana ': 1,
#  'Sarcodiotheca gaudichaudii ': 5,
#  'Sarcoglottis sceptrodes ': 1,
#  'Sarcoglottis speciosa ': 2,
#  'Sarcopoterium spinosum ': 2,
#  'Sarcostemma angustissimum ': 1,
#  'Sarcostemma crispum ': 8,
#  'Sarcostemma cynanchioides ': 3,
#  'Sarcostemma cynanchoides ': 2,
#  'Sarcostemma cynanchoides ssp. hartwegii ': 1,
#  'Sargassum albemarlense ': 3,
#  'Sargassum kjellmanianum ': 1,
#  'Sargassum muticum ': 10,
#  'Sargassum pacificum ': 1,
#  'Sargassum skottsbergii ': 1,
#  'Sargassum templetonii ': 1,
#  'Sargassum zacae ': 1,
#  'Saribus rotundifolius ': 4,
#  'Saritaea magnifica ': 1,
#  'Sarmienta repens ': 1,
#  'Sarracena minor var. okefenokeensis ': 1,
#  'Sarracenia ': 24,
#  'Sarracenia alabamensis ssp. alabamensis ': 16,
#  'Sarracenia alabamensis ssp. wherryi ': 8,
#  'Sarracenia alata ': 49,
#  'Sarracenia flava ': 19,
#  'Sarracenia flava var. atropurpurea ': 1,
#  'Sarracenia flava var. cuprea ': 11,
#  'Sarracenia flava var. flava ': 5,
#  'Sarracenia flava var. maxima ': 11,
#  'Sarracenia flava var. ornata ': 21,
#  'Sarracenia flava var. rubricorpora ': 11,
#  'Sarracenia flava var. rugelii ': 18,
#  'Sarracenia jonesii ': 29,
#  'Sarracenia leucophylla ': 68,
#  'Sarracenia minor ': 1,
#  'Sarracenia minor var. minor ': 21,
#  'Sarracenia minor var. okefenokeensis ': 10,
#  'Sarracenia oreophila ': 53,
#  'Sarracenia psittacina ': 30,
#  'Sarracenia purpurea ': 35,
#  'Sarracenia purpurea ssp. purpurea ': 58,
#  'Sarracenia purpurea ssp. purpurea f. heterophylla ': 6,
#  'Sarracenia purpurea ssp. venosa ': 22,
#  'Sarracenia purpurea ssp. venosa var. montana ': 44,
#  'Sarracenia rosea ': 24,
#  'Sarracenia rubra ssp. alabamensis ': 2,
#  'Sarracenia rubra ssp. gulfensis ': 11,
#  'Sarracenia rubra ssp. rubra ': 4,
#  'Sarracenia rubra ssp. viatorum ': 7,
#  'Sarracenia sp. ': 4,
#  'Sarracenia x catesbaei ': 1,
#  'Sarracenia x umlauftiana ': 3,
#  'Sarracenia Xformosa ': 2,
#  ...}

# %%
from collections import Counter

counted = Counter(species_pics)

counted.most_common(10)

# %%
len(set(counted.elements()))
# Out:
# 29814

# %%
counted.total()
# Out:
# 437982

# %%
for name, count in counted.items():
    if count == 1:
        print(name)
# Out:
# Fagopyrum tataricum
# Fagus orientalis
# Fallopia japonica var. japonica
# Falluga paradoxa
# Faradaya splendida
# Fascicularia pitcairnifolia
# Faucaria britteniae
# Fauchea laciniata
# Faxonia pusilla
# Felicia muricata
# Fenestraria rhopalophylla
# Ferocactus acanthodes
# Ferocactus echidnae var. echidnae
# Ferocactus fordii
# Ferocactus fordii var. fordii
# Ferocactus latispinus
# Ferocactus pottsii
# Ferocactus sinuatus
# Ferocactus stainesii
# Ferraria antherosa
# Ferraria crispa ssp. nortieri
# Festuca brachyphylla ssp. coloradoensis
# Festuca californica ssp. californica
# Festuca drymeja
# Festuca roemeri
# Fibigia clypeata
# Fibigia eriocarpa
# Ficinia truncata
# Ficus altissima
# Ficus audrey
# Ficus citrifolia
# Ficus repens
# Ficus thonningii
# Ficus tinctoria subsp. tinctoria
# Ficus trigonata
# Filago vulgaris
# Filicium decipiens
# Filipendula kamtschatica
# Fimbristylis puberula var. interior
# Firmiania simplex
# Flourensia oolepis
# Fockea edulis
# Fontinalis neomexicana
# Forestiera
# Forestiera arizonica
# Forestiera neomexicana
# Forestiera reticulata
# Fosterella rubsyi
# Fouquiera splendens
# Fouquieria fasciculata
# Fragaria gracilis
# Fragaria virginiana ssp. glauca
# Fraxinus chinensis
# Fraxinus gooddingii
# Fraxinus hopeinsis
# Fraxinus sp.
# Freycinetia banksii
# Fritillaria eastwoodiae vel aff.
# Fritillaria gibbosa
# Fritillaria graeca ssp. thessala var. meteora
# Fritillaria imperialis
# Fritillaria meleagris ssp. saturnus
# Fritillaria michailovskyi ssp. yellow form
# Fritillaria pyrenaica ssp. lutea
# Frullania bolanderi
# Fuchsia bracelineae
# Fuchsia cordifolia
# Fuchsia encliandra
# Fuchsia thymifolia var. variegata
# Fucus gardneri (=f. distichus)
# Fucus sp.
# Fumana thymifolia
# Fumaria densiflora
# Funaria sp.
# Funastrum cyanchoides var. hartwegii
# Furcraea guatemalensis
# Sabal causiarum
# Sabal etonia
# Sabatia angularis
# Sabatia campestris
# Sabatia difformis
# Sabatia sp.
# Saccharum officinarum
# Sageretia filiformis
# Sageretia wrightii
# Saintpaulia shumensis
# Saintpaulia teitensis
# Salicornia brachiata
# Salicornia perennis
# Saline hookeri
# Salix arctophila
# Salix barclayi
# Salix discolor cf.
# Salix helvetica
# Salix lucida
# Salix lucida caudata cf.
# Salix matsudana
# Salix rigida var. watsonii
# Salpinctium natalense
# Salvia alata
# Salvia alborosea
# Salvia anguicoma
# Salvia apiana x salvia chionopeplica
# Salvia areolata
# Salvia atrocalyx
# Salvia azurea
# Salvia benthamiana
# Salvia canriensis
# Salvia chrysophylla
# Salvia clevelandii X leucophylla
# Salvia coahuilensis
# Salvia consobrina
# Salvia cyanea
# Salvia cylindriflora
# Salvia d
# Salvia dominica
# Salvia excelsa
# Salvia gillesii
# Salvia hapalophylla
# Salvia iodantha
# Salvia karwinskiana
# Salvia karwinskii
# Salvia lanicaulis
# Salvia lyrata
# Salvia marci
# Salvia matudae
# Salvia medusa
# Salvia melissaeflora
# Salvia nellifera
# Salvia nubilorum
# Salvia nutans
# Salvia occidentalis
# Salvia occlusa
# Salvia palealis
# Salvia palestina
# Salvia pallida
# Salvia peninsularis
# Salvia pennellii
# Salvia peregrina
# Salvia psilantha
# Salvia psilostachya
# Salvia pulchella
# Salvia rhodostephana
# Salvia rosmarinus
# Salvia rubrifaux
# Salvia secundiflora
# Salvia sellowiana
# Salvia sharpii
# Salvia silvarum
# Salvia somalensis
# Salvia subrubens
# Salvia subscandens
# Salvia trichostephana
# Salvia univerticillata
# Salvia urica
# Salvinia molesta (left) and salvinia minima (right)
# Sambucus caerulea
# Sambucus microbotorys
# Sambucus nigra subsp. caerulea
# Sanchezia speciosa
# Sanguisorba sp.
# Sanicula chinensis
# Sanicula tuberosas
# Saniculata bipinnata
# Sannantha sp.
# Sansevieria ehrenbergii
# Sansevieria suffruticosa
# Sansevieria trifasciata var. trifasciata
# Sanseviieria pearsonii
# Sapindus drummondii
# Sapium
# Sapium sebiferum
# Saponaria pumila
# Saraca declinata
# Saraca indica
# Sarcocaulon inerme
# Sarcochilus hartmannii
# Sarcococca ruscifolia
# Sarcocoronia pacifica
# Sarcodiotheca ecuadoreana
# Sarcoglottis sceptrodes
# Sarcostemma angustissimum
# Sarcostemma cynanchoides ssp. hartwegii
# Sargassum kjellmanianum
# Sargassum pacificum
# Sargassum skottsbergii
# Sargassum templetonii
# Sargassum zacae
# Saritaea magnifica
# Sarmienta repens
# Sarracena minor var. okefenokeensis
# Sarracenia flava var. atropurpurea
# Sarracenia minor
# Sarracenia x catesbaei
# Sarracenia Xharperi
# Sarracenia Xmitchelliana
# Sarracenia Xnaczii
# Sasa sp.
# Satureja montana
# Saurauia angustifolia
# Saussurea tilesii
# Saxifraga allendale-duo
# Saxifraga allendale-goblin
# Saxifraga alpigena
# Saxifraga andersonii
# Saxifraga arco-valleyi ssp. ophelia
# Saxifraga bridget
# Saxifraga brookside
# Saxifraga brunoniana
# Saxifraga burseriana ssp. crenata
# Saxifraga burseriana ssp. gallahad
# Saxifraga burseriana ssp. gloria
# Saxifraga burseriana ssp. john tomlinson
# Saxifraga burseriana ssp. princess
# Saxifraga callosa
# Saxifraga cebennensis
# Saxifraga cecilia
# Saxifraga cumulus
# Saxifraga diapensioides
# Saxifraga eschscholtzii
# Saxifraga georgei
# Saxifraga grisbachii
# Saxifraga hirsuta
# Saxifraga micranthidifolia
# Saxifraga nelsoniana
# Saxifraga obtusa
# Saxifraga platysepala
# Saxifraga rebunshirensis
# Saxifraga rufidula
# Saxifraga serpyllifolia
# Saxifraga tricuspidata
# Saxifraga umbrosa
# Saxifraga virginiensis
# Scabiosa atropurpurea var. maritima
# Scabiosa turolensis
# Scalesia villosa
# Scapania undulata var. undulata
# Resnova megaphylla
# Restrepia antennifera var. antennifera
# Restrepia macolatum
# Restrepia sp.
# Restrepia sp. (sanguina?)
# Retrophyllum respigliosii
# Rhagodia candolleana
# Rhagodia sp.
# Rhagodia sp. / chenopodium
# Rhamnus alpina
# Rhamnus insula
# Rhamnus mucronata
# Rhamnus tomentella
# Rhamnus tomentella ssp. cuspidata
# Rhaphidophora tetrasperma
# Rhaphithamnus venusta
# Rhapis excelsa
# Rhaponticum centauroides
# Rheum australe
# Rhexia alifanus
# Rhinanthus glacialis
# Rhinanthus minor
# Rhinephyllum grandiforme
# Rhinephyllum muirii
# Rhinotropis californica
# Rhipsalis aculeata
# Rhipsalis cereuscula
# Rhipsalis crispata
# Rhipsalis paradoxicus
# Rhipsalis salicornioides
# Rhizocarpon geographicum
# Rhizoclonium rhizophilum
# Rhizoclonium robustum
# Rhizomnium glabrescens
# Rhizophora stylosa
# Rhodedendron occidentale
# Rhodendron macrophyllum
# Rhodiola pachyclados
# Rhododendren occidentale
# Rhododendron anagalliflorum
# Rhododendron arboreum ssp. albotomentosum
# Rhododendron bagobonum
# Rhododendron bodenii
# Rhododendron brachycarpum
# Rhododendron burmanicum
# Rhododendron catawbiense
# Rhododendron caucasicum
# Rhododendron compylogynum var. myrtilloides
# Rhododendron correoides
# Rhododendron cyrtophyllum
# Rhododendron daphnoides
# Rhododendron degronianum ssp. yakushimanum
# Rhododendron dielsianum
# Rhododendron dilatatum
# Rhododendron diversipilosum
# Rhododendron fictolacteum
# Rhododendron glaucophyllum
# Rhododendron griersonianum
# Rhododendron irroratum ssp. yiliangense
# Rhododendron jasminiflorum
# Rhododendron johnstoneanum x rhododendron moupinense
# Rhododendron kanehirae
# Rhododendron leucaspis
# Rhododendron leytense var. loheri
# Rhododendron luteum
# Rhododendron macgregoriae
# Rhododendron maddenii ssp. crassum
# Rhododendron makinoi
# Rhododendron mjobergii
# Rhododendron moupinense
# Rhododendron nubicola
# Rhododendron orbiculare
# Rhododendron pachysanthum
# Rhododendron periclymenoides
# Rhododendron pseudochrysanthum
# Rhododendron rugosum var. kinabaluense
# Rhododendron searsiae
# Rhododendron setosum var. macranthum
# Rhododendron siderophyllum
# Rhododendron ungerni
# Rhododendron vireya
# Rhododendron viscosum
# Rhododendron weyrichii
# Rhododendron wiltonii
# Rhododendron xanthostephanum
# Rhododendron yedoense var. poukhanense
# Rhododendron yungningense
# Rhodohypoxis baurii
# Rhus cismontana
# Rhus copallina
# Rhus radicans
# Rhus semialata
# Rhus taitensis
# Rhus trichocarpa
# Rhus virens var. virens
# Rhyncholaelia glauca
# Rhynchosia minima
# Rhynchospora nervosa
# Rhynchostylis gigantea
# Rhytidiadelphus loreus
# Ribes alpinum
# Ribes californicum var. californicum;
# Ribes divaricatum ssp. divaricatum
# Ribes leptanthus
# Ribes roezlii var. amictum
# Ribes sanguieneum
# Ribes viscosissmum
# Riccardia multifida
# Riccia beyrichiana
# Richea pandanifolia
# Rigeron compositus
# Ris missouriensis
# Rodriguezia bahiensis
# Primula lismore ssp. pink ice
# Primula macrocalyx
# Primula malacoides
# Primula marginata
# Primula maximowiczii
# Primula minkwitziae
# Primula nutans
# Primula pauciflora var. pulchellum
# Primula polyanthus
# Primula primulina
# Primula pulchra
# Primula redolens
# Primula reinei ssp. kitakadensis
# Primula renifolia
# Primula tschuktschorum
# Primula voronovi
# Primula x pubescens
# Prionitis albemarlensis
# Prionitis galapagensis
# Prionitis hancockii
# Prionitis linearis
# Prionium serratum
# Pritchardia gordonii
# Pritchardia thurstonii
# Proboscidea fragrans
# Proboscidea gracillima
# Proboscidea louisianica ssp louisianica
# Proboscidea parviflora ssp. parviflora
# Proboscidea triloba ssp. diversifolia
# Proiphys amboinensis
# Prosaptia pubipes
# Prosaptia rosenstockii
# Prosartes disporum
# Prosartes hookeri var. oregana
# Prosopis strombulifera
# Prostanthera ovalifolia
# Prosthechea cochleata
# Protea caffra
# Protea gaguedi
# Protea longifolia
# Protea magnifica
# Protea nana
# Prunus blireana
# Prunus cerasifera var. pissardii
# Prunus dulcis var. dulcis
# Prunus hintonii
# Prunus mandshurica
# Prunus minutiflora
# Prunus mume
# Prunus persica var. nucipersica
# Prunus takasaga-montana
# Prunus takasago-montana
# Psathyrotes sp.
# Pseudananas sagenarius
# Pseudephebe pubescens
# Pseuderanthemum carruthersii var. atropurpureum
# Pseuderanthemum carruthersii var. carruthersii
# Pseudobahia hermannii
# Pseudobraunia californica
# Pseudocalliergon trifarium
# Pseudocydonia sinensis
# Pseudolaingia hancockii
# Pseudolithos cubiformis
# Pseudopanax arboreus
# Pseudopanax crassifolius
# Pseudopanax laetum
# Pseudotsuga menziesii ssp. glauca
# Psidium guava
# Psidium guineense
# Psilocarphus elatior
# Psilocarphus sp.
# Psilocarphus tenellus var. tenellus
# Psilocaulon junceum
# Psittacanthus calyculatus
# Psoralea aculeata
# Psoralea macrostachya
# Psorothamnus sp.
# Psychilis bifida
# Psychopsis papilio
# Psychotria costivenia ssp. altorum
# Psychotria ligustrifolia
# Psydrax obovata ssp. obovata
# Psygmorchis pusilla
# Pterideridea parishii
# Pteridium aquilinum var. latiusculum
# Pteridium esculentum
# Pteris boliviensis
# Pteris dactylina
# Pteris dentata
# Pteris ensiformis 'Victoriae'
# Pteris incompleta
# Pteris krameri
# Pteris lellingeri
# Pteris nuda
# Pteris venezuelensis
# Pteris websteri
# Pterocarpus officinalis
# Pterocarya sp.
# Pterocladiella capillacea
# Pteronia divaricata
# Pterosiphonia paucicorticata
# Pteryxia terebinthina var. terebinthina
# Ptychosperma elegans
# Pueraria phaseoloides
# Pulmonaria obscura
# Pulsatilla albana ssp. armena
# Pulsatilla slavica
# Pulsatilla vulgaris ssp. grandis
# Pultenaea juniperina
# Purshia glandulosa
# Puya boliviensis
# Puya coerulea
# Puya laxa
# Puya spathacea
# Pyracantha crenatiserrata
# Pyrethropsis hosmariense
# Pyrola asarifolia ssp. bracteata
# Pyrrocoma
# Pyrus communis x pyrus pyrifolia
# Pyrus melanocarpa
# Pyxidanthera barbulata
